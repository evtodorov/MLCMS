# %%
from ipywidgets import interact
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import sympy as sy
from mpl_toolkits import mplot3d

# %%
# %matplotlib notebook

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Task 2

# %%
x, alpha = sy.symbols('x alpha')
ex6 = alpha - x**2
ex7 = alpha - 2*x**2 - 3

# %%
ex6
# Out:
# alpha - x**2

# %%
sy.solveset(ex6, x)
# Out:
# FiniteSet(sqrt(alpha), -sqrt(alpha))

# %%
sol7 = sy.solveset(ex7, x)
sol7
# Out:
# FiniteSet(-sqrt(2)*sqrt(alpha - 3)/2, sqrt(2)*sqrt(alpha - 3)/2)

# %%
alpha_num= np.linspace(-1,1,20)[:, None]

# %%
alpha_plot = np.linspace(-1, 1, 100)
branch1 = np.sqrt(alpha_plot)
branch2 = -np.sqrt(alpha_plot)
plt.figure()
plt.scatter(alpha_plot, branch1, label='stable')
plt.scatter(alpha_plot, branch2, label='unstable')
plt.legend()
plt.xlabel(r"$\alpha$")
plt.ylabel(r"$x_\infty$")
plt.xlim([-1, 1])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def task2_1t(alpha=1.):
    T, Y = np.meshgrid( np.arange(0,2,0.1), np.arange(-2,2,0.1))
    U = np.ones(T.shape)
    V = alpha - Y**2
    plt.figure()
    plt.streamplot(T, Y, U, V)
    plt.xlabel(r'$t$')
    plt.ylabel(r'$x$')
interact(task2_1t)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=-1.0), Output()), _dom_classes=…
# <function __main__.task2_1t(alpha=1.0)>

# %%
def task2_1x(alpha=1.):
    X, Y = np.meshgrid( np.arange(-2,2,0.1), np.arange(-2,2,0.1))
    U = alpha - X**2
    V = -Y
    plt.figure()
    plt.streamplot(X, Y, U, V)
    plt.xlabel(r'$x$')
    plt.ylabel(r'$x_2 = - \dot x_2$')
interact(task2_1x)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='alpha', max=3.0, min=-1.0), Output()), _dom_classes=…
# <function __main__.task2_1x(alpha=1.0)>

# %%
alpha_plot2 = np.linspace(0, 5)
lam7_1 = sy.lambdify(alpha, sol7.args[0], 'numpy')
lam7_2 = sy.lambdify(alpha, sol7.args[1], 'numpy')
plt.figure()
plt.scatter(alpha_plot2, lam7_1(alpha_plot2), label='stable')
plt.scatter(alpha_plot2, lam7_2(alpha_plot2), label='unstable')
plt.xlabel(r"$\alpha$")
plt.ylabel(r"$x_\infty$")
plt.xlim([0, 5])
plt.grid()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def task2_2(alpha=2.):
    T, Y = np.meshgrid( np.arange(0,2,0.1), np.arange(-2,2,0.1))
    U = np.ones(T.shape)
    V = alpha - 2*Y**2 - 3
    plt.figure()
    plt.streamplot(T, Y, U, V)
    plt.xlabel(r"$\alpha$")
    plt.ylabel(r"$x_\infty$")
interact(task2_2)
# Out:
# interactive(children=(FloatSlider(value=2.0, description='alpha', max=6.0, min=-2.0), Output()), _dom_classes=…
# <function __main__.task2_2(alpha=2.0)>
