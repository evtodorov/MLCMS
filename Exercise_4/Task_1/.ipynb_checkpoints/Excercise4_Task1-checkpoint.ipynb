# %%
from PCA_part1 import pca_svd_from_file
import matplotlib.pyplot as plt
import scipy as sc
import matplotlib.image as mpimg
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import preprocessing
import numpy as np
from PIL import Image

# %%
#val = pca_svd_from_file()
pca_text_file = pd.read_csv('pca_dataset.txt', delimiter=' ')

plt.rcParams['figure.figsize'] = [16,8]

nPoints = 99
X = pca_text_file.to_numpy()

fig = plt.figure()
ax1 = fig.add_subplot(121)
ax1.plot(X[:,0],X[:,1],'.')
ax1.grid()
ax1.axis('equal')
ax1.set_xlabel('x-coordinate')
ax1.set_ylabel('y-coordinate')

Xavg = np.mean(X,axis=0)
B = X - np.tile(Xavg,(nPoints,1))

U, S, VT = np.linalg.svd((B.T)/np.sqrt(100))

ax2 = fig.add_subplot(122)
ax2.plot(X[:,0],X[:,1],'.')
ax2.grid()
ax2.plot(np.array([Xavg[0],Xavg[0]+U[0,0]*S[0]]),np.array([Xavg[1],Xavg[1]+U[1,0]*S[0]]),'-',color='red',label='Principal components')
ax2.plot(np.array([Xavg[0],Xavg[0]+U[0,1]*S[1]]),np.array([Xavg[1],Xavg[1]+U[1,1]*S[1]]),'-',color='red')
ax2.legend()
ax2.axis('equal')
ax2.set_xlabel('x-coordinate')
ax2.set_ylabel('y-coordinate')

comp1_p1,comp1_p2 = np.array([Xavg[0],Xavg[0]+U[0,0]*S[0]]),np.array([Xavg[1],Xavg[1]+U[1,0]*S[0]])
comp2_p1,comp2_p2 = np.array([Xavg[0],Xavg[0]+U[0,1]*S[1]]),np.array([Xavg[1],Xavg[1]+U[1,1]*S[1]])
      
plt.show()

# %%
# Projecting the data set on the first Principal Component

pc1_x = np.dot(X[:,0],VT[0,:])
pc1_y = np.dot(X[:,1],VT[0,:])

plt.plot([0,pc1_x],[0,pc1_y])
plt.legend("Approx. 1D linear subspace")

# %% [markdown]
# # Energy contained in each component

# %%
#Energy in the first component
S_comp1 = (S[0]*S[0])/sum(S*S)
print(S_comp1)
#Energy in the second component
S_comp2 = (S[1]*S[1])/sum(S*S)
print(S_comp2)
# Out:
# 0.9929871280253522
# 0.007012871974647905

# %%
# Checking if the lines are orthogonal to each other
slope_product = np.dot(comp1_p2 - comp1_p2, comp2_p2 - comp2_p2)
print(slope_product)
# Out:
# 0.0

# %% [markdown]
# ## PCA with Image data

# %%
#Original Image data that is being used
original_image_data =  sc.misc.face()

resized_image_data = np.array(Image.fromarray(original_image_data).resize(size=(249, 185)))
plt.imshow(resized_image_data)
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %%
#Gray scale image of the original that has been resized is being used
gray_image_data = np.array(Image.fromarray(sc.misc.face(gray=True)).resize(size=(249, 185)))
image_size = gray_image_data.shape
plt.imshow(gray_image_data,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %%
X_img_avg = np.mean(gray_image_data,axis=0)
B_img = gray_image_data - np.tile(X_img_avg,(image_size[0],1))

U_img, S_img, VT_img = np.linalg.svd((B_img.T)/np.sqrt(image_size[1]))

# %% [markdown]
# # Image with all principal components

# %%
S_img_eye = S_img*np.eye(U_img.shape[0],VT_img.shape[0])
constr_data = np.matmul(np.matmul(U_img,S_img_eye),VT_img)

plt.imshow(constr_data.T,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %% [markdown]
# # Image with 120 principal component

# %%
S_img_120 = np.zeros(S_img.shape)
S_img_120[0:120] = S_img[0:120]

S_img_eye_120 = S_img_120*np.eye(U_img.shape[0],VT_img.shape[0])
constr_data_120 = np.matmul(np.matmul(U_img,S_img_eye_120),VT_img)

plt.imshow(constr_data_120.T,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %% [markdown]
# # Image with 50 principal component

# %%
S_img_50 = np.zeros(S_img.shape)
S_img_50[0:50] = S_img[0:50]

S_img_eye_50 = S_img_50*np.eye(U_img.shape[0],VT_img.shape[0])
constr_data_50 = np.matmul(np.matmul(U_img,S_img_eye_50),VT_img)

plt.imshow(constr_data_50.T,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %% [markdown]
# # Image with 10 principal component

# %%
S_img_10 = np.zeros(S_img.shape)
S_img_10[0:10] = S_img[0:10]

S_img_eye_10 = S_img_10*np.eye(U_img.shape[0],VT_img.shape[0])
constr_data_10 = np.matmul(np.matmul(U_img,S_img_eye_10),VT_img)

plt.imshow(constr_data_10.T,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 248.5, 184.5, -0.5)

# %%
# Calculating the number of components required for loss to be less than 1%
total_sum = np.sum(S_img*S_img)
cumm_sum = 0.0
num_1percent = -1
for i in range(S_img.shape[0]):
    cumm_sum = cumm_sum  + (S_img[i]*S_img[i])
    
    if (1-(cumm_sum/total_sum)) < 0.01:
        num_1percent = i
        break

print("The number of components required for loss less than 1% = ")
print(num_1percent)
# Out:
# The number of components required for loss less than 1% =
# 87

# %% [markdown]
# # Pedestrian Data

# %%
# Reading the data from the data_DMAP_PCA_vadere.txt file
ped_pca_vadere_text = pd.read_csv('data_DMAP_PCA_vadere.txt', delimiter=' ')
ped_data_array = ped_pca_vadere_text.to_numpy()

#print(ped_data_array)
#print(ped_data_array.shape)

fig = plt.figure()
ax1 = fig.add_subplot(121)
ax1.plot(ped_data_array[:,0],ped_data_array[:,1],'.')
ax1.grid()

ax2 = fig.add_subplot(122)
ax2.plot(ped_data_array[:,2],ped_data_array[:,3],'.')
ax2.grid()

# %%
#printing the path of all the pedestrians
plt.scatter(ped_data_array[:,0],ped_data_array[:,1])
plt.scatter(ped_data_array[:,2],ped_data_array[:,3])
plt.scatter(ped_data_array[:,4],ped_data_array[:,5])
plt.scatter(ped_data_array[:,6],ped_data_array[:,7])
plt.scatter(ped_data_array[:,8],ped_data_array[:,9])
plt.scatter(ped_data_array[:,10],ped_data_array[:,11])
plt.scatter(ped_data_array[:,12],ped_data_array[:,13])
plt.scatter(ped_data_array[:,14],ped_data_array[:,15])
plt.scatter(ped_data_array[:,16],ped_data_array[:,17])
plt.scatter(ped_data_array[:,18],ped_data_array[:,19])
plt.scatter(ped_data_array[:,20],ped_data_array[:,21])
plt.scatter(ped_data_array[:,22],ped_data_array[:,23])
plt.scatter(ped_data_array[:,24],ped_data_array[:,25])
plt.scatter(ped_data_array[:,26],ped_data_array[:,27])
plt.scatter(ped_data_array[:,28],ped_data_array[:,29])

# %%
Xavg_ped = np.mean(ped_data_array,axis=0)
B_ped = ped_data_array - np.tile(Xavg_ped,(999,1))

U_ped, S_ped, VT_ped = np.linalg.svd((B_ped)/np.sqrt(1000))

#print(ped_data_array.shape)
#print(U_ped.shape)
#print(S_ped.shape)
#print(VT_ped.shape)

total_sum = np.sum(S_ped*S_ped)
pca_energy_ratio = (S_ped[0]*S_ped[0]+S_ped[1]*S_ped[1])/total_sum
cumm_ped_sum = 0.0
num_1percent_ped = -1

for i in range(S_ped.shape[0]):
    cumm_ped_sum = cumm_ped_sum  + (S_ped[i]*S_ped[i])
    if (cumm_sum/total_sum) > 0.9:
        num_1percent_ped = i

pca1_data = np.zeros((ped_data_array.shape[0],1))
pca2_data = np.zeros((ped_data_array.shape[0],1))

for j in range(ped_data_array.shape[0]):
    pca1_data[j] = np.dot(ped_data_array[j,:],VT_ped[0])
    pca2_data[j] = np.dot(ped_data_array[j,:],VT_ped[1])

    
print("The percentage captured by the first two principal components = ",pca_energy_ratio)
print("The number of principal components to capture more than 90% = ",num_1percent_ped)
plt.scatter(ped_data_array[:,0],pca1_data,label='x-data pca1')
plt.scatter(ped_data_array[:,1],pca1_data,label='y-data pca1')
plt.legend()
# Out:
# The percentage captured by the first two principal components =  0.8492175627834597
# The number of principal components to capture more than 90% =  29

# %%
plt.scatter(ped_data_array[:,0],pca2_data,label='x-data pca2')
plt.scatter(ped_data_array[:,1],pca2_data,label='y-data pca2')

# %%
plt.scatter(pca1_data,pca2_data)
