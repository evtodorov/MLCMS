# %%
from PCA_part1 import pca_svd_from_file
import matplotlib.pyplot as plt
import scipy as s
import matplotlib.image as mpimg
import pandas as pd

# %%
val = pca_svd_from_file()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(val.T[:,0],val.T[:,1])
plt.show()

# %%
pic_var = scipy.misc.face()
#pic_var.shape
#image = mpimg.imread(scipy.misc.face())
#plt.imshow(image)
plt.imshow(pic_var[:,:,0],"gray_r")

# %%
pca_text_file = pd.read_csv('pca_dataset.txt', delimiter=' ')
#pca_text_file
plt.figure()
plt.scatter(pca_text_file.to_numpy()[:,0],pca_text_file.to_numpy()[:,1])
