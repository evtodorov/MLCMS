# %%
from VAE import MNIST, VAE

# %%
mnist = MNIST()

# %%
shape = mnist.X_train[0].shape

# %%
vae2 = VAE(shape, 2)
# Out:
# WARNING:tensorflow:From D:\Documents\TUM\Crowd Modelling\repos\Exercise_4\Task_3\VAE.py:25: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.
#
# WARNING:tensorflow:From D:\Documents\TUM\Crowd Modelling\repos\Exercise_4\Task_3\VAE.py:28: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Documents\TUM\Crowd Modelling\repos\Exercise_4\Task_3\VAE.py:44: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\etodorov\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# ...

# %%
#vae2.train(mnist.X_train, mnist.X_test, 5, 128)

# %%
vae2.train(mnist.X_train, mnist.X_test, 200, 128, threshold=0.0001,
           plot_params = {'type': 'imshow',
                          'print_epochs':[0,1,5,25,50],
                          'plot_samples':15,
                          'y_test': mnist.Y_test})
# Out:
# WARNING:tensorflow:From D:\Documents\TUM\Crowd Modelling\repos\Exercise_4\Task_3\VAE.py:105: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From D:\Documents\TUM\Crowd Modelling\repos\Exercise_4\Task_3\VAE.py:106: The name tf.train.MonitoredSession is deprecated. Please use tf.compat.v1.train.MonitoredSession instead.
#
# WARNING:tensorflow:From C:\Users\etodorov\anaconda3\envs\tf1\lib\site-packages\tensorflow_core\python\ops\array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Epoch 0 elbo -811.457 reconstruction -811.3551 divergence 0.097820126
# ...

# %%
vae32 = VAE(shape, 32)
vae32.train(mnist.X_train, mnist.X_test, 200, 128, threshold=0.0001,
           plot_params = {'type': 'imshow',
                          'print_epochs':[0,1,5,25,50],
                          'plot_samples':15,
                          'y_test': mnist.Y_test})
# Out:
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Epoch 0 elbo -817.0587 reconstruction -811.75104 divergence 5.3081923
# Epoch 1 elbo -210.7874 reconstruction -201.1628 divergence 9.575509
# 441.3465
# 557.3105
# 616.1385
# Epoch 5 elbo 660.0178 reconstruction 727.1537 divergence 66.83505
# 692.9199
# 712.05237
# 732.19495
# 745.0674
# 757.8795
# 772.8566
# 778.7905
# 789.3268
# 797.4991
# 798.1433
# 804.0881
# 805.2313
# 811.7571
# 822.0561
# 823.9047
# 823.8103
# 826.12866
# 828.0446
# 824.584
# Epoch 25 elbo 835.6979 reconstruction 914.2963 divergence 78.914
# 832.4636
# 831.2145
# 835.8412
# 837.7327
# 842.7702
# 844.0489
# 839.2594
# 841.5136
# 841.4954
# 848.2134
# 847.8576
# 845.985
# 852.9521
# 852.195
# 851.2007
# 849.382
# 846.9474
# 857.6554
# 854.8458
# 854.8076
# 857.9562
# 857.6934
# 860.4875
# 864.7204
# Epoch 50 elbo 858.7328 reconstruction 941.311 divergence 82.72281
# 860.1758
# 863.9561
# ...
