# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from helper_functions import *

# %% [markdown]
# ## Plotting the closed 1D manifold

# %%
data = np.genfromtxt('data/takens_1.txt')
print(data)
plt.plot(data[:,0],data[:,1])
# Out:
# [[ 2.16837096 -0.54631259]
#  [ 2.17981061 -0.53247518]
#  [ 2.19002807 -0.51894034]
#  ...
#  [ 2.14086777 -0.5761134 ]
#  [ 2.15555144 -0.56069056]
#  [ 2.16853679 -0.54611965]]

# %% [markdown]
# ## Plotting the first coordinate with respect to time
# #### The data is plotted with all the given points, without delay

# %%
time = [i for i in range(data.shape[0])]
t_plot = np.array(time)
plt.plot(t_plot,data[:,0])

# %% [markdown]
# ## Plotting the delayed dataset
# #### Only every 10th entry is taken into account

# %%
t_delay = time[0::10]
data_delay1 = data[:,0][0::10]
data_delay2 = data[:,0][10:1000]
plt.plot(t_delay,data_delay)

# %%
plt.plot(data[:,0][0:100],data_delay1)

# %%
plt.plot(data[:,0][0:990],data_delay2)
