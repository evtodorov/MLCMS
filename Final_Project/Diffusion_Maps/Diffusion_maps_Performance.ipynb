# %% [markdown]
# ## Performance of self and Datafold implementations of Diffusion Maps

# %%
import numpy
import pandas as pd
from sklearn.manifold import SpectralEmbedding
from sklearn.datasets import make_swiss_roll, make_s_curve
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Swiss roll dataset - Increasing number of Datapoints

# %%
data = pd.read_csv('../Performance_data/DM_time_swiss.txt', index_col='N')
data.head()
data.plot(y = [0], label=['Datafold'])
plt.title('Mean running time for Datafold, Swiss roll')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %%
data = pd.read_csv('../Performance_data/DM_time_swiss.txt', index_col='N',nrows=6)
data.head()
data.plot(y = [2], label=['Self implemented'])
plt.title('Mean running time for self implemented algorithm, Swiss roll')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %% [markdown]
# ### S-curve dataset - Increasing number of Datapoints

# %%
data = pd.read_csv('../Performance_data/DM_time_scurve.txt', index_col='N')
data.head()
data.plot(y = [0], label=['Datafold'])
plt.title('Mean running time for Datafold, S-curve')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %%
data = pd.read_csv('../Performance_data/DM_time_scurve.txt', index_col='N')
data.head()
data.plot(y = [2], label=['Self implemented'])
plt.title('Mean running time for self implemented algorithm, S-curve')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %% [markdown]
# ### Swiss roll - increasing number of dimensions

# %%
data = pd.read_csv('../Performance_data/DM_noise_time_swiss.txt', index_col='N')
data.head()
data.plot(y = [0], label=['Datafold'])
plt.title('Mean running time for Datafold, S-curve')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %%
data = pd.read_csv('../Performance_data/DM_noise_time_swiss.txt', index_col='N',nrows=6)
data.head()
data.plot(y = [2], label=['Self implemented'])
plt.title('Mean running time for self implemented algorithm, Swiss roll')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %% [markdown]
# ### S-curve - increasing number of dimensions

# %%
data = pd.read_csv('../Performance_data/DM_noise_time_scurve.txt', index_col='N')
data.head()
data.plot(y = [0], label=['Datafold'])
plt.title('Mean running time for Datafold, S-curve')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()

# %%
data = pd.read_csv('../Performance_data/DM_noise_time_scurve.txt', index_col='N',nrows=5)
data.head()
data.plot(y = [2], label=['Self implemented'])
plt.title('Mean running time for self implemented algorithm, S-curve')
plt.xlabel('N', fontsize = 15)
plt.ylabel('Time [s]', fontsize = 15)
plt.show()
