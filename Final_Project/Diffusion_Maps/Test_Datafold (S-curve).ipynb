# %%
import math
import numpy as np
from diffusions_maps import diffusion_map
from noise_dim import add_noise_dim
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
from sklearn.datasets import make_s_curve
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
# %matplotlib inline
plt.rcParams['figure.dpi'] = 50 # For memory saving purposes



import datafold.dynfold as dfold
import datafold.pcfold as pfold
from datafold.dynfold import LocalRegressionSelection
from datafold.utils.plot import plot_pairwise_eigenvector

# %% [markdown]
# ## 1 noise dimension

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,1)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.05404164266436529, cut-off=0.9977393679709288

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 2 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,2)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.07892350356322424, cut-off=1.2057465166162997

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 3 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,3)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.09796729513365476, cut-off=1.343363043635492

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 5 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,5)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.18344326478390519, cut-off=1.838246396763132

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 10 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,10)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.302681672859147, cut-off=2.3612713657654383

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 20 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,20)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.5526345097080918, cut-off=3.1905961623846104

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 30 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,30)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.7782017853424029, cut-off=3.7861598806925936

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 50 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_s_curve(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,50)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=1.38892522803083, cut-off=5.058156601250811

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)
