# %%
import math
import numpy as np
from diffusions_maps import diffusion_map
from noise_dim import add_noise_dim
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
from sklearn.datasets import make_s_curve
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
# %matplotlib inline
plt.rcParams['figure.dpi'] = 50 # For memory saving purposes



import datafold.dynfold as dfold
import datafold.pcfold as pfold
from datafold.dynfold import LocalRegressionSelection
from datafold.utils.plot import plot_pairwise_eigenvector

# %% [markdown]
# ## 1 noise dimension

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,1)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.6557708799456426, cut-off=3.4755929020326013

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 2 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,2)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.9390965103894878, cut-off=4.159182252035189

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 3 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,3)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=1.13396711945479, cut-off=4.570387979331294

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 5 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,5)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.7398353080270733, cut-off=3.6916486848385746

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 10 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,10)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=0.8915636073536853, cut-off=4.052555807634084

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 20 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,20)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=1.2481593414251717, cut-off=4.79499163148122

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 30 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,30)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=1.4360748764338622, cut-off=5.143294355099562

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)

# %% [markdown]
# ## 50 noise dimensions

# %%
nr_samples = 5000
idx_plot = np.random.permutation(nr_samples)[0:nr_samples]
X_wo_n, X_color = make_swiss_roll(nr_samples, random_state=3, noise=0)

# %%
# Adding noise to data
X = add_noise_dim(X_wo_n,50)

# %%
X_pcm = pfold.PCManifold(X)
X_pcm.optimize_parameters()

print(f"epsilon={X_pcm.kernel.epsilon}, cut-off={X_pcm.cut_off}")
# Out:
# epsilon=2.100438156457474, cut-off=6.2202492476201465

# %%
dmap = dfold.DiffusionMaps(
    kernel=pfold.GaussianKernel(epsilon=X_pcm.kernel.epsilon),
    n_eigenpairs=9,
    dist_kwargs=dict(cut_off=X_pcm.cut_off),
)
dmap = dmap.fit(X_pcm)
evecs, evals = dmap.eigenvectors_, dmap.eigenvalues_

plot_pairwise_eigenvector(
    eigenvectors=dmap.eigenvectors_[idx_plot, :],
    n=1,
    fig_params=dict(figsize=[15, 15]),
    scatter_params=dict(cmap=plt.cm.Spectral, c=X_color[idx_plot]),
)
