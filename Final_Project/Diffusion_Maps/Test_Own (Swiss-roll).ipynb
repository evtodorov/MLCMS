# %%
import math
import numpy as np
from diffusions_maps import diffusion_map
from noise_dim import add_noise_dim
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
from sklearn.datasets import make_s_curve
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
# %matplotlib inline
plt.rcParams['figure.dpi'] = 50 # For memory saving purposes



import datafold.dynfold as dfold
import datafold.pcfold as pfold
from datafold.dynfold import LocalRegressionSelection
from datafold.utils.plot import plot_pairwise_eigenvector

# %%
N_1 = 5000
X_es1, t1 = make_swiss_roll(N_1, random_state = 1337)

# %% [markdown]
# ## 1 noise dimension

# %%
X_es1_n1 = add_noise_dim(X_es1,1)
# Out:
# [[  4.47150101   9.68614616   5.62010305  -0.38149945]
#  [  6.19038897   0.0851299   -0.46661541  -0.82838913]
#  [  3.64594004  18.99448381   6.36316211   0.02486903]
#  ...
#  [ -3.09571458   1.33648354   7.63547208   0.86447116]
#  [  2.41195115  15.09626019  -4.60136254   0.70346461]
#  [ -1.90953038   4.93335445 -10.64827153  -0.32229306]]

# %%
num_values_1 = 10
λ_n1, Φ_n1 = diffusion_map(X_es1_n1, num_values_1)
print(f'λ of shape {np.shape(λ_n1)} and values: \n \n {λ_n1}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99660313 0.99668813 0.99723184 0.99757778 0.9977933  0.99784238
#  0.99881739 0.99947395 0.99986833 1.        ]

# %%
Φ_1_flipped_n1 = np.fliplr(Φ_n1) # Flip to get in order of decending λ
hor_axis_eigen_n1 = Φ_1_flipped_n1.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n1, Φ_1_flipped_n1[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 2 noise dimensions

# %%
X_es1_n2 = add_noise_dim(X_es1,2)
# Out:
# [[ 4.47150101e+00  9.68614616e+00  5.62010305e+00 -4.89230685e-01
#   -6.02715627e-01]
#  [ 6.19038897e+00  8.51299009e-02 -4.66615408e-01  1.24881418e+00
#    3.78443382e-01]
#  [ 3.64594004e+00  1.89944838e+01  6.36316211e+00  4.62919362e-01
#   -7.31867882e-02]
#  ...
#  [-3.09571458e+00  1.33648354e+00  7.63547208e+00  3.45737305e-01
#    1.36258987e-03]
#  [ 2.41195115e+00  1.50962602e+01 -4.60136254e+00  3.94070932e-01
#   -3.79918640e-01]
#  [-1.90953038e+00  4.93335445e+00 -1.06482715e+01  8.22354956e-01
#    8.84623100e-01]]

# %%
num_values_1 = 10
λ_n2, Φ_n2 = diffusion_map(X_es1_n2, num_values_1)
print(f'λ of shape {np.shape(λ_n2)} and values: \n \n {λ_n2}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99666765 0.99679276 0.99728192 0.99761147 0.99786454 0.99793441
#  0.99884892 0.99948745 0.99987388 1.        ]

# %%
Φ_1_flipped_n2 = np.fliplr(Φ_n2) # Flip to get in order of decending λ
hor_axis_eigen_n2 = Φ_1_flipped_n2.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n2, Φ_1_flipped_n2[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 3 noise dimensions

# %%
X_es1_n3 = add_noise_dim(X_es1,3)
# Out:
# [[  4.47150101   9.68614616   5.62010305   0.40660864   0.32258349
#    -0.42512158]
#  [  6.19038897   0.0851299   -0.46661541   1.01885062  -0.73711335
#    -0.11874403]
#  [  3.64594004  18.99448381   6.36316211  -0.44180662  -0.25008877
#     0.67133168]
#  ...
#  [ -3.09571458   1.33648354   7.63547208   0.38453072   0.2841116
#    -0.81847566]
#  [  2.41195115  15.09626019  -4.60136254   0.25499857  -0.04360148
#    -0.073248  ]
#  [ -1.90953038   4.93335445 -10.64827153   0.06641534  -0.49781343
#     0.18105036]]

# %%
num_values_1 = 10
λ_n3, Φ_n3 = diffusion_map(X_es1_n3, num_values_1)
print(f'λ of shape {np.shape(λ_n3)} and values: \n \n {λ_n3}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99683069 0.99699329 0.99739816 0.99773089 0.99795878 0.99803767
#  0.99889299 0.99950944 0.99987875 1.        ]

# %%
Φ_1_flipped_n3 = np.fliplr(Φ_n3) # Flip to get in order of decending λ
hor_axis_eigen_n3 = Φ_1_flipped_n3.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n3, Φ_1_flipped_n3[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 5 noise dimensions

# %%
X_es1_n5 = add_noise_dim(X_es1,5)
# Out:
# [[ 4.47150101e+00  9.68614616e+00  5.62010305e+00 ...  2.35532130e-01
#    5.11216281e-02 -1.33172190e-03]
#  [ 6.19038897e+00  8.51299009e-02 -4.66615408e-01 ... -1.46462784e-01
#    3.77203817e-01 -4.25112245e-01]
#  [ 3.64594004e+00  1.89944838e+01  6.36316211e+00 ...  5.86585326e-02
#    1.10325915e-01 -1.18081972e+00]
#  ...
#  [-3.09571458e+00  1.33648354e+00  7.63547208e+00 ...  1.54003994e+00
#   -1.67434746e-01 -4.36889323e-02]
#  [ 2.41195115e+00  1.50962602e+01 -4.60136254e+00 ... -1.22731035e+00
#   -7.03806851e-01  2.72276176e-01]
#  [-1.90953038e+00  4.93335445e+00 -1.06482715e+01 ...  7.58815258e-01
#   -6.68643321e-01  2.55894135e-01]]

# %%
num_values_1 = 10
λ_n5, Φ_n5 = diffusion_map(X_es1_n5, num_values_1)
print(f'λ of shape {np.shape(λ_n5)} and values: \n \n {λ_n5}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99725092 0.99739156 0.99772531 0.99803519 0.99826283 0.99828946
#  0.99905948 0.99957756 0.99989504 1.        ]

# %%
Φ_1_flipped_n5 = np.fliplr(Φ_n5) # Flip to get in order of decending λ
hor_axis_eigen_n5 = Φ_1_flipped_n5.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n5, Φ_1_flipped_n5[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 10 noise dimensions

# %%
X_es1_n10 = add_noise_dim(X_es1,10)
# Out:
# [[  4.47150101   9.68614616   5.62010305 ...  -0.42484734  -0.05582992
#     0.63657804]
#  [  6.19038897   0.0851299   -0.46661541 ...   0.37187748   0.54847351
#    -0.87708265]
#  [  3.64594004  18.99448381   6.36316211 ...   0.12535083   0.55210983
#     0.44727445]
#  ...
#  [ -3.09571458   1.33648354   7.63547208 ...  -0.66702856  -0.30730089
#    -0.05485996]
#  [  2.41195115  15.09626019  -4.60136254 ...  -0.06900074  -0.35665217
#    -0.15438791]
#  [ -1.90953038   4.93335445 -10.64827153 ...   0.18693075   0.32535136
#    -0.03161349]]

# %%
num_values_1 = 10
λ_n10, Φ_n10 = diffusion_map(X_es1_n10, num_values_1)
print(f'λ of shape {np.shape(λ_n10)} and values: \n \n {λ_n10}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99831031 0.99843659 0.9985511  0.99877324 0.99898123 0.99900175
#  0.99943494 0.99974813 0.9999392  1.        ]

# %%
Φ_1_flipped_n10 = np.fliplr(Φ_n10) # Flip to get in order of decending λ
hor_axis_eigen_n10 = Φ_1_flipped_n10.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n10, Φ_1_flipped_n10[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 20 noise dimensions

# %%
X_es1_n20 = add_noise_dim(X_es1,20)
# Out:
# [[  4.47150101   9.68614616   5.62010305 ...   0.30148961   0.0559054
#     0.05000084]
#  [  6.19038897   0.0851299   -0.46661541 ...  -1.1823062   -0.28137084
#    -1.14486298]
#  [  3.64594004  18.99448381   6.36316211 ...  -0.27998427   0.44280294
#    -0.87821912]
#  ...
#  [ -3.09571458   1.33648354   7.63547208 ...   0.02246251  -0.16937457
#     0.02700826]
#  [  2.41195115  15.09626019  -4.60136254 ...   0.07624179   0.70071875
#     0.49072319]
#  [ -1.90953038   4.93335445 -10.64827153 ...   0.31079297   0.55214046
#    -0.23258439]]

# %%
num_values_1 = 10
λ_n20, Φ_n20 = diffusion_map(X_es1_n20, num_values_1)
print(f'λ of shape {np.shape(λ_n20)} and values: \n \n {λ_n20}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99971446 0.99973674 0.99976637 0.99980343 0.99983309 0.99985132
#  0.99990866 0.99995715 0.99999003 1.        ]

# %%
Φ_1_flipped_n20 = np.fliplr(Φ_n20) # Flip to get in order of decending λ
hor_axis_eigen_n20 = Φ_1_flipped_n20.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n20, Φ_1_flipped_n20[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 30 noise dimensions

# %%
X_es1_n30 = add_noise_dim(X_es1,30)
# Out:
# [[  4.47150101   9.68614616   5.62010305 ...  -1.25934511  -0.43394816
#     1.85845812]
#  [  6.19038897   0.0851299   -0.46661541 ...  -0.26496801   0.23205982
#    -0.15580904]
#  [  3.64594004  18.99448381   6.36316211 ...   0.02926074  -0.23406053
#    -0.30898139]
#  ...
#  [ -3.09571458   1.33648354   7.63547208 ...   0.81926028   0.26367307
#     0.70553522]
#  [  2.41195115  15.09626019  -4.60136254 ...  -0.44466196   0.23420279
#    -0.59058669]
#  [ -1.90953038   4.93335445 -10.64827153 ...   0.41802864   1.00960521
#    -0.2876156 ]]

# %%
num_values_1 = 10
λ_n30, Φ_n30 = diffusion_map(X_es1_n30, num_values_1)
print(f'λ of shape {np.shape(λ_n30)} and values: \n \n {λ_n30}')
# Out:
# λ of shape (10,) and values:
#
#  [0.99998395 0.99998486 0.99998589 0.99998909 0.99999027 0.99999143
#  0.99999543 0.99999589 0.99999894 1.        ]

# %%
Φ_1_flipped_n30 = np.fliplr(Φ_n30) # Flip to get in order of decending λ
hor_axis_eigen_n30 = Φ_1_flipped_n30.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n30, Φ_1_flipped_n30[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()

# %% [markdown]
# ## 50 noise dimensions

# %%
X_es1_n50 = add_noise_dim(X_es1,50)
# Out:
# [[  4.47150101   9.68614616   5.62010305 ...  -0.53674048   0.3449138
#     0.07260638]
#  [  6.19038897   0.0851299   -0.46661541 ...  -0.25549926  -0.16259423
#    -1.12070716]
#  [  3.64594004  18.99448381   6.36316211 ...  -0.39670912  -0.582313
#    -1.07008291]
#  ...
#  [ -3.09571458   1.33648354   7.63547208 ...   0.52938465   0.65594851
#    -0.13497213]
#  [  2.41195115  15.09626019  -4.60136254 ...   0.65275509   1.03843082
#     0.43227195]
#  [ -1.90953038   4.93335445 -10.64827153 ...   0.26129284  -0.22110394
#     0.2763893 ]]

# %%
num_values_1 = 10
λ_n50, Φ_n50 = diffusion_map(X_es1_n50, num_values_1)
print(f'λ of shape {np.shape(λ_n50)} and values: \n \n {λ_n50}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-17071ec60aee> in <module>
#       1 num_values_1 = 10
# ----> 2 λ_n50, Φ_n50 = diffusion_map(X_es1_n50, num_values_1)
#       3 print(f'λ of shape {np.shape(λ_n50)} and values: \n \n {λ_n50}')
#
# D:\Academics\M.S. Computational Science and Engineering\21 Summer\ML and Crowd modeling simualtion\Git_project_files\MLCMS_GroupB\Final_Project\Diffusion_Maps\diffusions_maps.py in diffusion_map(data, k)
#      46
#      47     # Step 8
# ---> 48     a_l, v_l = eigsh(T, k)
#      49
#      50     # Step 9
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1685     with _ARPACK_LOCK:
#    1686         while not params.converged:
# -> 1687             params.iterate()
#    1688
#    1689         return params.extract(return_eigenvectors)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in iterate(self)
#     547             # compute y = Op*x
#     548             if self.mode == 1:
# --> 549                 self.workd[yslice] = self.OP(self.workd[xslice])
#     550             elif self.mode == 2:
#     551                 self.workd[xslice] = self.OPb(self.workd[xslice])
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in _matvec(self, x)
#     197         will define matrix-vector multiplication as well.
#     198         """
# --> 199         return self.matmat(x.reshape(-1, 1))
#     200
#     201     def matvec(self, x):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in matmat(self, X)
#     335                              % (self.shape, X.shape))
#     336
# --> 337         Y = self._matmat(X)
#     338
#     339         if isinstance(Y, np.matrix):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in _matmat(self, X)
#     729
#     730     def _matmat(self, X):
# --> 731         return self.A.dot(X)
#     732
#     733     def _adjoint(self):
#
# KeyboardInterrupt:

# %%
Φ_1_flipped_n50 = np.fliplr(Φ_n50) # Flip to get in order of decending λ
hor_axis_eigen_n50 = Φ_1_flipped_n50.T[1]
for i in range(2, num_values_1):
    plt.figure()
    plt.scatter(hor_axis_eigen_n50, Φ_1_flipped_n50[:,i], s=5, c=t1, cmap='winter')
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.locator_params(axis='x', nbins=5)
    plt.xlabel(fr'$\phi_1$', fontsize = 30)
    plt.ylabel(fr'$\phi_{i}$', fontsize = 30)
    plt.show()
